# %% [markdown]
# ## 패키지란 무엇인가?
# 패키지(Packages)는 도트(.)를 사용하여 파이썬 모듈을 계층적(디렉터리 구조)으로 관리할 수 있게 해준다.
# 예를 들어 모듈 이름이 A.B인 경우 A는 패키지 이름이고 B는 A패키지의 B모듈이 된다.

# %%
# 가상의 game 패키지 예

game/
    __init__.py
    sound/
        __init__.py
        echo.py
        wav.py
    graphic/
        __init__.py
        screen.py
        render.py
    play/
        __init__.py
        run.py
        test.py

# %% [markdown]
# game,sound,graphic,play는 디렉터리/확장자가.py인 파일은 파이썬 모듈<br>
# game 디렉터리가 패키지의 루트 디렉터리이고 sound, graphic, play는 서브 디렉터리

# %% [markdown]
# ### 패키지 만들기

# %% [markdown]
# #### 패키지의 기본 구성 요소 준비하기

# %% [markdown]
# 1. C:\doit디렉터리 밑에 game 및 기타 서브 디렉터리를 생성하고 필요한 .py파일들은 만든다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 여기서 만든 game패키지를 참조할 수 있도록 명령 프롬프트 창에서 set 명령어로 PYTHONPATH 환경변수에 C:\doit 디렉터리를 추가한다. 그리고 파이썬 인터프리터 실행
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 패키지 안의 함수 실행하기

# %% [markdown]
# 첫 번째 echo 모듈을 import하여 실행
# ![image.png](attachment:image.png)
#
# 두 번째 echo 모듈이 있는 디렉터리까지를 from .. import 하여 실행
# ![image-2.png](attachment:image-2.png)
#
# 세 번째 echo 모듈의 echo_test함수를 직접 import하여 실행
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# echo_test 함수 사용하는 것 불가능
#
# ![image.png](attachment:image.png)
# 도트 연산자를(.)사용해서 import a,b,c처럼 import 할 때 가장 마지막 항목인 c는 반드시 모듈 또는 패키지여야만 한다!

# %% [markdown]
# ### 언더바언더바init언더바언더바.py의 용도

# %% [markdown]
# __init__.py파일은 해당 디렉터리가 패키지의 일부임을 알려주는 역할을 한다. 만약 game,sound,graphic 등 패키지에 포함된 디렉터리에
# __init__.py파일이 없다면 패키지로 인식되지 않는다.
#
# 하지만 python 3.3버전 부터는 __init__.py파일 없어도 패키지로 인식!!!! 3.11버전 임으로 없어도 됨,, 그래서 삭제했당

# %% [markdown]
# ###  relative 패키지
# graphic 디렉터리의 render.py모듈이 sound 디렉터리의 echo.py 모듈을 사용하고 싶다면 어떻게 해야할까? render.py를 수정!

# %%
# render.py

from game.sound.echo import echo_test
def render_test():
    print("render")
    echo_test()

# %%
from game.sound.echo import echo_test
render_test()
# Out:
# render
# echo

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ..은 render.py 파일의 부모 디렉터리를 의미
# 따라서 render.py파일의 부모 디렉터리는 game이므로 import 가능
# render.py파일의 현재 디렉터리는 graphic이다
#
# - .. 부모 디렉터리
# - . 현재 디렉터리
