# %% [markdown]
# 모듈이란 함수나 변수 또는 클래스를 모아 놓은 파이썬 파일이다.<br>
# 모듈은 다른 파이썬 프로그램에서 불러와 사용할 수 있게끔 만든 파이썬 파일이라고 할 수 있다.<br>
# 파이썬으로 프로그래밍을 할 때 굉장히 많은 모듈 사용함....<br>
# 다른 사람이 이미 만들어 놓은 모듈을 사용할 수도 있고, 직접 만들어서 사용할 수도 있다. 모듈을 어떻게 만들고 사용할 수 있는지 알아보자.

# %% [markdown]
# ### 모듈 불러오기

# %%
import mod1

# %%
print(mod1.add(3,4))
# Out:
# 7

# %%
print(mod1.sub(4,2))
# Out:
# 2

# %%
from mod1 import add
add(3,4)
# Out:
# 7

# %%
from mod1 import add,sub
sub(10,5)
# Out:
# 5

# %%
from mod1 import *   # *문자는 모든 것
add(1,2)
# Out:
# 3

# %% [markdown]
# ### if__name__ == "__main__":의 의미

# %% [markdown]
# if__name__ == "__main__"을 사용하면 C:/doit>python mod1.py처럼 직접 이 파일을 실행했을 때는 __name__ == "__main__"이 참이 되어 if문 다음 문장이 실행된다. 반대로 대화형 인터프리터나 다른 파일에서 이 모듈을 불러서 사용할 때는 거짓이 되어 if문 다음 문장이 수행되지 않는다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### __name__ 변수란?
#
# 파이썬의 __name__변수는 파이썬이 내부적으로 사용하는 특별한 변수 이름.
#
# 만약 C:/doit>python mod1.py 처럼 직접 파일을 실행할 경우 mod1.py의 __name__변수에는 __main__ 값이 저장된다.
# 하지만 파이썬 셀이나 다른 파이썬 모듈에서 mod1을 import할 경우에는 mod1.py의 __name__ 변수에는 mod1.py의 모듈 이름 값 mod1이 저장된다.

# %%
import mod1
mod1.__name__
# Out:
# 'mod1'

# %% [markdown]
# ### 클래스나 변수 등을 포함한 모듈

# %%
import mod2
print(mod2.PI)
# Out:
# 3.141592

# %%
a = mod2.Math()
print(a.solve(2))
# Out:
# 12.566368

# %%
print(mod2.add(mod2.PI, 4.4))
# Out:
# 7.5415920000000005

# %% [markdown]
# ### 다른 파일에서 모듈 불러오기(modtest.py)

# %%
import modtest
# Out:
# 7

# %% [markdown]
# ### 모듈을 불러오는 또 다른 방법
# ![image.png](attachment:image.png)
#
# sys모듈은 파이썬을 설치할 때 함께 설치되는 라이브러리 모듈이다.
# sys모듈을 사용하면 파이썬 라이브러리가 설치되어 있는 디렉터리를 확인할 수 있다.

# %% [markdown]
# #### sys.path.append 사용하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### PYTHONPATH 환경 변수 사용하기
#
# ![image.png](attachment:image.png)
#
# set명령어를 사용해 PYTHONPATH 환경 변수에 mod2.py파일이 있는 C:\doit\mymod 디렉터리를 설정한다.
#
# 맥이나 유닉스 환경에서는 set대신 export명령을 사용해야 한다.
